# %%
import pandas as pd
import numpy as np

# %%
link= "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
df=pd.read_csv(link,header=None)

# %%
df.head()
# Out:
#    0    1            2    3    4     5   ...    20   21    22  23  24     25
# 0   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  13495
# 1   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  16500
# 2   1    ?  alfa-romero  gas  std   two  ...   9.0  154  5000  19  26  16500
# 3   2  164         audi  gas  std  four  ...  10.0  102  5500  24  30  13950
# 4   2  164         audi  gas  std  four  ...   8.0  115  5500  18  22  17450
#
# [5 rows x 26 columns]

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns=headers

# %%
df.head(10)
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
# 5          2                 ?         audi  ...       19          25  15250
# 6          1               158         audi  ...       19          25  17710
# 7          1                 ?         audi  ...       19          25  18920
# 8          1               158         audi  ...       17          20  23875
# 9          0                 ?         audi  ...       16          22      ?
#
# [10 rows x 26 columns]

# %%
df1=df.replace('?',np.NaN)

# %%
df1=df1.dropna(subset=['price'],axis=0)

# %%
df1.head(10)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3               NaN  alfa-romero  ...       21          27  13495
# 1           3               NaN  alfa-romero  ...       21          27  16500
# 2           1               NaN  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2               NaN         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1               NaN         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 10          2               192          bmw  ...       23          29  16430
#
# [10 rows x 26 columns]

# %%
df1.to_csv('auto.csv')

# %%
df1.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df1.describe()
# Out:
#         symboling  wheel-base  ...    city-mpg  highway-mpg
# count  201.000000  201.000000  ...  201.000000   201.000000
# mean     0.840796   98.797015  ...   25.179104    30.686567
# std      1.254802    6.066366  ...    6.423220     6.815150
# min     -2.000000   86.600000  ...   13.000000    16.000000
# 25%      0.000000   94.500000  ...   19.000000    25.000000
# 50%      1.000000   97.000000  ...   24.000000    30.000000
# 75%      2.000000  102.400000  ...   30.000000    34.000000
# max      3.000000  120.900000  ...   49.000000    54.000000
#
# [8 rows x 10 columns]

# %%
df1.describe(include="all")
# Out:
#          symboling normalized-losses    make  ...    city-mpg highway-mpg price
# count   201.000000               164     201  ...  201.000000  201.000000   201
# unique         NaN                51      22  ...         NaN         NaN   186
# top            NaN               161  toyota  ...         NaN         NaN  6229
# freq           NaN                11      32  ...         NaN         NaN     2
# mean      0.840796               NaN     NaN  ...   25.179104   30.686567   NaN
# std       1.254802               NaN     NaN  ...    6.423220    6.815150   NaN
# min      -2.000000               NaN     NaN  ...   13.000000   16.000000   NaN
# 25%       0.000000               NaN     NaN  ...   19.000000   25.000000   NaN
# 50%       1.000000               NaN     NaN  ...   24.000000   30.000000   NaN
# 75%       2.000000               NaN     NaN  ...   30.000000   34.000000   NaN
# max       3.000000               NaN     NaN  ...   49.000000   54.000000   NaN
#
# ...

# %%
df1['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 201, dtype: object

# %%
df1['normalized-losses']=df1['normalized-losses'].astype('float')

# %%
mean=df1['normalized-losses'].mean()

# %%
df1['normalized-losses'].replace(np.nan,mean)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 201, dtype: float64

# %%
pd.get_dummies(df1["engine-location"])
# Out:
#      front  rear
# 0        1     0
# 1        1     0
# 2        1     0
# 3        1     0
# 4        1     0
# ..     ...   ...
# 200      1     0
# 201      1     0
# 202      1     0
# 203      1     0
# 204      1     0
#
# [201 rows x 2 columns]

# %%
import matplotlib.pylab as plt

# %%
missingdata=df1.isnull()

# %%
missingdata
# Out:
#      symboling  normalized-losses   make  ...  city-mpg  highway-mpg  price
# 0        False               True  False  ...     False        False  False
# 1        False               True  False  ...     False        False  False
# 2        False               True  False  ...     False        False  False
# 3        False              False  False  ...     False        False  False
# 4        False              False  False  ...     False        False  False
# ..         ...                ...    ...  ...       ...          ...    ...
# 200      False              False  False  ...     False        False  False
# 201      False              False  False  ...     False        False  False
# 202      False              False  False  ...     False        False  False
# 203      False              False  False  ...     False        False  False
# 204      False              False  False  ...     False        False  False
#
# [201 rows x 26 columns]

# %%
for column in missingdata.columns.values.tolist():
   print(column)
   print(missingdata[column].value_counts())
   print("")
# Out:
# symboling
# False    201
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      37
# Name: normalized-losses, dtype: int64
#
# make
# False    201
# Name: make, dtype: int64
#
# fuel-type
# False    201
# Name: fuel-type, dtype: int64
#
# aspiration
# False    201
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    199
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    201
# Name: body-style, dtype: int64
#
# drive-wheels
# False    201
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    201
# Name: engine-location, dtype: int64
#
# wheel-base
# False    201
# Name: wheel-base, dtype: int64
#
# length
# False    201
# Name: length, dtype: int64
#
# width
# False    201
# Name: width, dtype: int64
#
# height
# False    201
# Name: height, dtype: int64
#
# curb-weight
# False    201
# Name: curb-weight, dtype: int64
#
# engine-type
# False    201
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %%
avg_norm_loss=df1['normalized-losses'].mean(axis=0)

# %%
avg_norm_loss
# Out:
# 122.0

# %%
df1['bore']=df1['bore'].astype("float")

# %%
df1['bore'].replace(np.nan,df1['bore'].mean(),inplace=True)

# %%
df1['bore']
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 201, dtype: float64

# %%
df1['stroke']=df1['stroke'].astype("float")

# %%
avg_bore=df1['stroke'].mean()
avg_bore
# Out:
# 3.2569035532994857

# %%
df1['stroke'].replace(np.nan,avg_bore,inplace=True)

# %%
df1['stroke'].isnull().value_counts()
# Out:
# False    201
# Name: stroke, dtype: int64

# %%
df1['engine-type'].value_counts().idxmax()
# Out:
# 'ohc'

# %%
df1['length'] = df1['length']/df1['length'].max()

# %%
df1["horsepower"].replace("?",np.nan,inplace=True)

# %%
df1["horsepower"]=df1["horsepower"].astype('float')

# %%
df1['horsepower'].mean()
# Out:
# 103.39698492462311

# %%
df1["horsepower"].replace(np.nan,df1['horsepower'].mean(),inplace=True)

# %%
df1["horsepower"]=df1["horsepower"].astype('int64',copy=True)

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
# %matplotlib inline

plt.pyplot.hist(df["horsepower"])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bin=np.linspace(min(df1["horsepower"]),max(df1["horsepower"]),4)
bin
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupnames=['low','medium','high']

# %%
df1['HP_bin']=pd.cut(df1['horsepower'],bin,labels=groupnames,include_lowest=True)
df1[['horsepower','HP_bin']]
# Out:
#      horsepower  HP_bin
# 0           111     low
# 1           111     low
# 2           154  medium
# 3           102     low
# 4           115     low
# ..          ...     ...
# 200         114     low
# 201         160  medium
# 202         134  medium
# 203         106     low
# 204         114     low
#
# [201 rows x 2 columns]

# %%
df1['HP_bin'].value_counts()
# Out:
# low       153
# medium     43
# high        5
# Name: HP_bin, dtype: int64

# %%
pyplot.bar(groupnames, df1["HP_bin"].value_counts())

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
dum1=pd.get_dummies(df['fuel-type'])

# %%
dum1
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [205 rows x 2 columns]

# %%
dum1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dum1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
df1=pd.concat([df1,dum1],axis=1)

# %%
df1
# Out:
#      symboling  normalized-losses  ... fuel-type-diesel fuel-type-gas
# 0          3.0                NaN  ...                0             1
# 1          3.0                NaN  ...                0             1
# 2          1.0                NaN  ...                0             1
# 3          2.0              164.0  ...                0             1
# 4          2.0              164.0  ...                0             1
# ..         ...                ...  ...              ...           ...
# 200       -1.0               95.0  ...                0             1
# 201       -1.0               95.0  ...                0             1
# 202       -1.0               95.0  ...                0             1
# 203       -1.0               95.0  ...                1             0
# 204       -1.0               95.0  ...                0             1
#
# [205 rows x 29 columns]

# %%
df1.drop("fuel-type",axis=1,inplace=True)

# %%
df1['aspiration']
# Out:
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 200      std
# 201    turbo
# 202      std
# 203    turbo
# 204    turbo
# Name: aspiration, Length: 205, dtype: object

# %%
dum2=pd.get_dummies(df1['aspiration'])

# %%
dum2
# Out:
#      std  turbo
# 0      1      0
# 1      1      0
# 2      1      0
# 3      1      0
# 4      1      0
# ..   ...    ...
# 200    1      0
# 201    0      1
# 202    1      0
# 203    0      1
# 204    0      1
#
# [205 rows x 2 columns]

# %%
dum2.drop("std",axis=1,inplace=True)

# %%
dum2
# Out:
#      turbo
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 200      0
# 201      1
# 202      0
# 203      1
# 204      1
#
# [205 rows x 1 columns]

# %%
dum2.rename(columns={"turbo":"new asp"},inplace=True)

# %%
dum2
# Out:
#      new asp
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 200        0
# 201        1
# 202        0
# 203        1
# 204        1
#
# [205 rows x 1 columns]

# %%
df1=pd.concat([df1,dum2],axis=1)

# %%
df1
# Out:
#      symboling  normalized-losses  ... fuel-type-gas new asp
# 0          3.0                NaN  ...             1       0
# 1          3.0                NaN  ...             1       0
# 2          1.0                NaN  ...             1       0
# 3          2.0              164.0  ...             1       0
# 4          2.0              164.0  ...             1       0
# ..         ...                ...  ...           ...     ...
# 200       -1.0               95.0  ...             1       0
# 201       -1.0               95.0  ...             1       1
# 202       -1.0               95.0  ...             1       0
# 203       -1.0               95.0  ...             0       1
# 204       -1.0               95.0  ...             1       1
#
# [205 rows x 29 columns]

# %%
avg_norm_loss
# Out:
# 122.0

# %%
df1['normalized-losses'].replace(np.nan,avg_norm_loss,inplace=True)

# %%
df1
# Out:
#      symboling  normalized-losses  ... fuel-type-gas new asp
# 0          3.0              122.0  ...             1       0
# 1          3.0              122.0  ...             1       0
# 2          1.0              122.0  ...             1       0
# 3          2.0              164.0  ...             1       0
# 4          2.0              164.0  ...             1       0
# ..         ...                ...  ...           ...     ...
# 200       -1.0               95.0  ...             1       0
# 201       -1.0               95.0  ...             1       1
# 202       -1.0               95.0  ...             1       0
# 203       -1.0               95.0  ...             0       1
# 204       -1.0               95.0  ...             1       1
#
# [205 rows x 29 columns]

# %%
missingdata=df1.isnull()

# %%
missingdata
# Out:
#      symboling  normalized-losses  ...  fuel-type-gas  new asp
# 0        False              False  ...          False    False
# 1        False              False  ...          False    False
# 2        False              False  ...          False    False
# 3        False              False  ...          False    False
# 4        False              False  ...          False    False
# ..         ...                ...  ...            ...      ...
# 200      False              False  ...          False    False
# 201      False              False  ...          False    False
# 202      False              False  ...          False    False
# 203      False              False  ...          False    False
# 204      False              False  ...          False    False
#
# [205 rows x 29 columns]

# %%
for columns in missingdata.columns.values.tolist():
  print(columns)
  print(missingdata[columns].value_counts())
  print("")
# Out:
# symboling
# False    201
# True       4
# Name: symboling, dtype: int64
#
# normalized-losses
# False    205
# Name: normalized-losses, dtype: int64
#
# make
# False    201
# True       4
# Name: make, dtype: int64
#
# aspiration
# False    201
# True       4
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    199
# True       6
# Name: num-of-doors, dtype: int64
#
# body-style
# False    201
# True       4
# Name: body-style, dtype: int64
#
# drive-wheels
# False    201
# True       4
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    201
# True       4
# Name: engine-location, dtype: int64
#
# wheel-base
# False    201
# True       4
# Name: wheel-base, dtype: int64
#
# length
# False    201
# True       4
# Name: length, dtype: int64
#
# width
# False    201
# True       4
# Name: width, dtype: int64
#
# height
# False    201
# True       4
# Name: height, dtype: int64
#
# curb-weight
# False    201
# True       4
# Name: curb-weight, dtype: int64
#
# ...

# %%
df1.describe(include='all')
# Out:
#          symboling  normalized-losses  ... fuel-type-gas     new asp
# count   201.000000         205.000000  ...    205.000000  205.000000
# unique         NaN                NaN  ...           NaN         NaN
# top            NaN                NaN  ...           NaN         NaN
# freq           NaN                NaN  ...           NaN         NaN
# mean      0.840796         122.000000  ...      0.902439    0.175610
# std       1.254802          31.681008  ...      0.297446    0.381419
# min      -2.000000          65.000000  ...      0.000000    0.000000
# 25%       0.000000         101.000000  ...      1.000000    0.000000
# 50%       1.000000         122.000000  ...      1.000000    0.000000
# 75%       2.000000         137.000000  ...      1.000000    0.000000
# max       3.000000         256.000000  ...      1.000000    1.000000
#
# [11 rows x 29 columns]

# %%
import numpy as np
import pandas as pd

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)

# %%
df.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  ...    diesel       gas
# symboling           1.000000           0.466264  ... -0.196735  0.196735
# normalized-losses   0.466264           1.000000  ... -0.101546  0.101546
# wheel-base         -0.535987          -0.056661  ...  0.307237 -0.307237
# length             -0.365404           0.019424  ...  0.211187 -0.211187
# width              -0.242423           0.086802  ...  0.244356 -0.244356
# height             -0.550160          -0.373737  ...  0.281578 -0.281578
# curb-weight        -0.233118           0.099404  ...  0.221046 -0.221046
# engine-size        -0.110581           0.112360  ...  0.070779 -0.070779
# bore               -0.140019          -0.029862  ...  0.054458 -0.054458
# stroke             -0.008245           0.055563  ...  0.241303 -0.241303
# compression-ratio  -0.182196          -0.114713  ...  0.985231 -0.985231
# horsepower          0.075819           0.217299  ... -0.169053  0.169053
# ...

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 53384.89479987011)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 48181.308866077794)

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
sns.boxplot(x='body-style',y='price',data=df)

# %%
sns.boxplot(x='engine-location',y='price',data=df)

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)

# %%
df.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %%
df.describe(include=['object'])
# Out:
#           make aspiration  ... fuel-system horsepower-binned
# count      201        201  ...         201               200
# unique      22          2  ...           8                 3
# top     toyota        std  ...        mpfi               Low
# freq        32        165  ...          92               115
#
# [4 rows x 10 columns]

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df_wheels=df['drive-wheels'].value_counts().to_frame()

# %%
df_wheels
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
df_wheels.rename(columns={"drive-wheels":"counts"},inplace=True)

# %%
df_wheels
# Out:
#      counts
# fwd     118
# rwd      75
# 4wd       8

# %%
df_wheels.index.name='drive-wheels'

# %%
df_wheels
# Out:
#               counts
# drive-wheels
# fwd              118
# rwd               75
# 4wd                8

# %%
df_loc=df['engine-location'].value_counts().to_frame()

# %%
df_loc
# Out:
#        engine-location
# front              198
# rear                 3

# %%
df_loc.rename(columns={'engine-location':'counts'},inplace=True)
df_loc.index.name='engine-location'

# %%
df_loc
# Out:
#                  counts
# engine-location
# front               198
# rear                  3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group1=df[['drive-wheels','body-style','price']]

# %%
df_group1
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
df_group1=df_group1.groupby(['drive-wheels'],as_index=False).mean()

# %%
df_group1
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot=grouped_test1.pivot(index='drive-wheels',columns='body-style')

# %%
grouped_pivot
# Out:
#                    price                ...
# body-style   convertible       hardtop  ...         sedan         wagon
# drive-wheels                            ...
# 4wd                  NaN           NaN  ...  12647.333333   9095.750000
# fwd              11595.0   8249.000000  ...   9811.800000   9997.333333
# rwd              23949.6  24202.714286  ...  21711.833333  16994.222222
#
# [3 rows x 5 columns]

# %%
grouped_pivot=grouped_pivot.fillna(0)

# %%
grouped_pivot
# Out:
#                    price                ...
# body-style   convertible       hardtop  ...         sedan         wagon
# drive-wheels                            ...
# 4wd                  0.0      0.000000  ...  12647.333333   9095.750000
# fwd              11595.0   8249.000000  ...   9811.800000   9997.333333
# rwd              23949.6  24202.714286  ...  21711.833333  16994.222222
#
# [3 rows x 5 columns]

# %%
avgbyBS=df[['body-style','price']]

# %%
grouped_test2=avgbyBS.groupby(['body-style'],as_index= False).mean()

# %%
grouped_test2
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
plt.pcolor(grouped_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig,ax=plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label
row_lable=grouped_pivot.columns.levels[1]
column_lable=grouped_pivot.index

#move ticks and labels
ax.set_xticks(np.arange(grouped_pivot.shape[1])+0.5)
ax.set_yticks(np.arange(grouped_pivot.shape[0])+0.5)

#insert lables
ax.set_yticklabels(column_lable)
ax.set_xticklabels(row_lable)

fig.colorbar(im)
plt.show()

# %%
sns.heatmap(grouped_pivot,xticklabels=grouped_pivot.columns.levels[1],yticklabels=grouped_pivot.index)
plt.show()

# %%
from scipy import stats

# %%
pearson_coef, p_value =stats.pearsonr(df['wheel-base'],df['price'])

# %%
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %%
pearson_coef, p_value =stats.pearsonr(df['horsepower'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559  with a P-value of P = 6.369057428260101e-48

# %%
pearson_coef, p_value =stats.pearsonr(df['length'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483638  with a P-value of P = 8.016477466159556e-30

# %%
pearson_coef, p_value =stats.pearsonr(df['width'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522673  with a P-value of P = 9.200335510481646e-38

# %%
grouped_test2=df_gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
f,p=stats.f_oneway(grouped_test2.get_group('4wd')['price'],grouped_test2.get_group('fwd')['price'],grouped_test2.get_group('rwd')['price'])

# %%
print( "ANOVA results: F=", f, ", P =", p)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
df.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)
